# %% [markdown]
# # Supermarket Sales Exploration
#
# Use this notebook to understand the dataset before building the dashboard.

# %%
from pathlib import Path

import pandas as pd

DATA_PATH = Path("..") / "data" / "SuperMarket Analysis.csv"
df = pd.read_csv(DATA_PATH)
df.head()

# %%
df.info()

# %%
df.isna().sum()

# %%
numeric_columns = ["Unit price", "Quantity", "Tax 5%", "Total", "cogs", "gross income", "Rating"]
df[numeric_columns].describe().T

# %%
kpis = {
    "Revenue": df["Total"].sum(),
    "Transactions": len(df),
    "Avg Rating": df["Rating"].mean(),
}
kpis
